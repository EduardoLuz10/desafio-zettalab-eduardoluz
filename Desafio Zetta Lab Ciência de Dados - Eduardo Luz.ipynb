# %%
import matplotlib.pyplot as plt

# Anos da série histórica
anos = list(range(1986, 2024))

# Dados de vegetação primária
veg_primaria = [
    115437709, 114532527.6, 113825131.3, 113273823.9, 112689281, 112091021.6,
    111475265.2, 110721113, 110132091.6, 109334185.3, 108461575.7, 107530379.3,
    106803259, 106001659.6, 105550810.9, 104713916.2, 103813501, 102927518.7,
    101942289, 101091170.9, 100312596.3, 99585307.68, 98975169.13, 98495521.53,
    98195061.72, 97861664.31, 97499979.44, 97172115.76, 96838013.56, 96465637.26,
    96127110.97, 95693075.96, 95260335.08, 94638985.07, 94103628.9, 93241557,
    92434296.55, 92009739.23
]

# Criando o gráfico
plt.figure(figsize=(12,6))
plt.plot(anos, veg_primaria, marker='o', color='green')
plt.title('Perda de Vegetação Primária no Pará (1986–2023)')
plt.xlabel('Ano')
plt.ylabel('Área de Vegetação Primária (ha)')
plt.grid(True)
plt.tight_layout()

# Salva o gráfico como imagem PNG
plt.savefig("grafico_vegetacao_primaria.png", dpi=300)

# Exibe o gráfico
plt.show()

# Dados da área total de vegetação secundária por ano no Pará
veg_secundaria = [
    1256.549266, 201892.8032, 347396.7617, 489138.2086, 815577.4122,
    1119183.686, 1237153.411, 1355670.449, 1392411.661, 1470401.174,
    1560281.485, 1582622.995, 1730353.314, 1822685.998, 1867009.41,
    1948523.804, 2071011.772, 2132404.643, 2168368.191, 2240074.721,
    2302193, 2401055.629, 2488917.685, 2623057.837, 2724508.106,
    2938754.477, 3160763.427, 3364532.616, 3491645.855, 3536754.355,
    3531320.892, 3597475.402, 3643297.59, 3745227.039, 3898978.824,
    4033921.151, 3953530.257, 3620621.517
]

# Cria gráfico de linha
plt.figure(figsize=(12,6))
plt.plot(anos, veg_secundaria, marker='o', color='limegreen')
plt.title('Evolução da Vegetação Secundária no Pará (1986–2023)')
plt.xlabel('Ano')
plt.ylabel('Área de Vegetação Secundária (ha)')
plt.grid(True)
plt.tight_layout()

# Salva imagem
plt.savefig("grafico_vegetacao_secundaria.png", dpi=300)
plt.show()

plt.figure(figsize=(12,6))

# Plotando ambas no mesmo eixo Y
plt.plot(anos, veg_primaria, label='Vegetação Primária', color='green', marker='o')
plt.plot(anos, veg_secundaria, label='Vegetação Secundária', color='limegreen', marker='o')

plt.title('Vegetação Primária vs. Secundária no Pará (1986–2023) - Escala Real')
plt.xlabel('Ano')
plt.ylabel('Área (ha)')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Salvar
plt.savefig("grafico_primaria_vs_secundaria_escala_real.png", dpi=300)
plt.show()

# Dados da supressão de vegetação primária no Pará (em hectares por ano)
supressao_primaria = [
    0, 807452.9706, 636490.8549, 513048.5987, 602611.0763, 557532.6187,
    747518.1378, 601973.9614, 634563.9245, 871474.2261, 738227.3909,
    883269.8408, 762115.6213, 628779.2826, 669696.1487, 861310.7345,
    817491.0763, 950513.7878, 1006778.376, 812411.3354, 768419.4925,
    651333.5623, 645651.8483, 448112.2987, 370465.2152, 312193.8696,
    316634.2096, 361859.5588, 338506.4977, 378540.8214, 461896.2218,
    382806.5568, 447162.0125, 587921.4481, 572395.527, 786192.3035,
    637488.8454, 357190.3015
]

# Gráfico de barras - Supressão da Vegetação Primária (em ha)
plt.figure(figsize=(14,6))
plt.bar(anos, supressao_primaria, color='indianred')

plt.title("Desmatamento Anual - Supressão de Vegetação Primária no Pará (1986–2023)", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área Desmatada (ha)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("04_supressao_primaria.png", dpi=300)
plt.show()

# Recuperação para Vegetação Secundária (em hectares)
recuperacao_secundaria = [
    199127.9053, 146362.1998, 151916.5318, 351681.7847, 332249.1065,
    198410.3262, 213411.3513, 136876.3532, 252432.8053, 201155.1717,
    173024.4333, 265892.6212, 214184.7584, 189963.0946, 264847.6278,
    266186.2951, 202935.1867, 230834.4344, 214428.2473, 218689.1143,
    244660.1811, 256734.8814, 272959.8212, 223959.8654, 321262.1019,
    350111.1778, 372049.2827, 301571.2038, 257321.3954, 245680.5564,
    273969.969, 238028.9054, 305819.481, 329790.7081, 255392.8819,
    140371.5376, 0, 0
]

# Gráfico de barras - Recuperação de Vegetação Secundária (em ha)
plt.figure(figsize=(14,6))
plt.bar(anos, recuperacao_secundaria, color='forestgreen')

plt.title("Recuperação de Vegetação Secundária no Pará (1986–2023)", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área Regenerada (ha)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("05_recuperacao_secundaria.png", dpi=300)
plt.show()

import numpy as np

# Largura das barras
bar_width = 0.4
x = np.arange(len(anos))

# Gráfico comparativo lado a lado
plt.figure(figsize=(14,6))
plt.bar(x - bar_width/2, supressao_primaria, width=bar_width, label='Supressão Primária', color='indianred')
plt.bar(x + bar_width/2, recuperacao_secundaria, width=bar_width, label='Recuperação Secundária', color='forestgreen')

plt.xticks(x, anos, rotation=45)
plt.title("Desmatamento vs. Recuperação no Pará (1986–2023)", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área (ha)", fontsize=12)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("03_comparativo_supressao_vs_recuperacao.png", dpi=300)
plt.show()

# Lista de anos
anos = list(range(1986, 2024))

# Supressão de Vegetação Secundária (em hectares)
supressao_secundaria = [
    0, 0, 0, 14327.24822, 26434.99379, 32831.87103, 89241.81347, 96958.25508,
    105881.9203, 180319.3701, 114523.3918, 157618.5097, 126106.8985, 121827.6132,
    157818.4467, 190889.8608, 147069.2229, 149975.3743, 203733.9121, 151290.1563,
    162157.0881, 151029.1983, 177033.9581, 145087.857, 132430.364, 115450.5455,
    135766.0679, 179213.3641, 190607.5844, 227159.9931, 274368.943, 218454.1565,
    213235.2342, 219939.6977, 191205.2581, 182757.1466, 215339.515, 186931.6539
]

# Gráfico de barras - Supressão da Vegetação Secundária (em ha)
plt.figure(figsize=(14,6))
plt.bar(anos, supressao_secundaria, color='saddlebrown')

plt.title("Supressão de Vegetação Secundária no Pará (1986–2023)", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área Desmatada (ha)", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("06_supressao_secundaria.png", dpi=300)
plt.show()

import numpy as np

# Definir largura das barras e posições
bar_width = 0.4
x = np.arange(len(anos))

# Gráfico de barras lado a lado
plt.figure(figsize=(14,6))
plt.bar(x - bar_width/2, supressao_secundaria, width=bar_width, label='Supressão Secundária', color='saddlebrown')
plt.bar(x + bar_width/2, recuperacao_secundaria, width=bar_width, label='Recuperação Secundária', color='forestgreen')

plt.xticks(x, anos, rotation=45)
plt.title("Supressão vs. Recuperação de Vegetação Secundária no Pará (1986–2023)", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área (ha)", fontsize=12)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("07_comparativo_secundaria.png", dpi=300)
plt.show()


import numpy as np
import matplotlib.pyplot as plt

# Posição base das barras
x = np.arange(len(anos))
bar_width = 0.25  # Largura das barras

# Gráfico de barras comparativo
plt.figure(figsize=(15,6))

plt.bar(x - bar_width, supressao_secundaria, width=bar_width, label='Supressão Secundária', color='saddlebrown')
plt.bar(x, recuperacao_secundaria, width=bar_width, label='Recuperação Secundária', color='forestgreen')
plt.bar(x + bar_width, supressao_primaria, width=bar_width, label='Supressão Primária', color='indianred')

plt.xticks(x, anos, rotation=45)
plt.title("Comparativo: Supressão e Recuperação de Vegetação no Pará (1986–2023)", fontsize=16)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área (ha)", fontsize=12)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig("08_comparativo_geral.png", dpi=300)
plt.show()
